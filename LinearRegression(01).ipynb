# %%
import pandas as pd
data = pd.read_csv('1000_Companies.csv')
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
X=data.iloc[:,[0,1,2,3]].values
Y=data.iloc[:,4].values
X
# Out:
# array([[165349.2, 136897.8, 471784.1, 'New York'],
#        [162597.7, 151377.59, 443898.53, 'California'],
#        [153441.51, 101145.55, 407934.54, 'Florida'],
#        ...,
#        [100275.47, 241926.31, 227142.82, 'California'],
#        [128456.23, 321652.14, 281692.32, 'California'],
#        [161181.72, 270939.86, 295442.17, 'New York']], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
X[:,3]=lb.fit_transform(X[:,3])
X
# Out:
# array([[165349.2, 136897.8, 471784.1, 2],
#        [162597.7, 151377.59, 443898.53, 0],
#        [153441.51, 101145.55, 407934.54, 1],
#        ...,
#        [100275.47, 241926.31, 227142.82, 0],
#        [128456.23, 321652.14, 281692.32, 0],
#        [161181.72, 270939.86, 295442.17, 2]], dtype=object)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

regressor=LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
accuracy=regressor.score(X_test,Y_test)
accuracy
# Out:
# 0.9135109655491428

# %%
new_data=[142107.34,91391.77,366168.42,'Florida']
new_data[3]=lb.fit_transform([new_data[3]])[0]

predict=regressor.predict([new_data])
print("The Return profit is= ",predict)
# Out:
# The Return profit is=  [139340.74692943]
